# %% [markdown]
# Let's go through what's necessary for the calculation of the thermal conductivity for any given time step during the TRT at specific locations:

# %%
# %matplotlib inline

# %% [markdown]
# 1. Read in the existing dataset: $T_s,T_r,Watts,t$, from the trt dataset
# 2. Find the gradient of temperature (whichever should be fine) to the natural log of hours, so your $m = \frac{dT}{d ln(t)}$
# 3. Using the gradient of the temperature, it is already possible to estimate the thermal conductivity, using $k_s = \frac{Q}{4\pi m}$
# 4. The thermal diffusivity can then be evaluated at $\alpha_s = \frac{k_s}{c_p}$,where the heat capacity is a known value: 37.5 in IP units
# 5. The borehole resistence may therefore be calculated as
# $R_b = \frac{1}{4\pi k_s}$ $(\frac{T_m - T_{rs}}{m}-ln\frac{4\alpha_s t}{r_b^2})$

# %% [markdown]
# The question then becomes... how do we evaluate the thermal conductivity at different depths of the well? It actually is pretty simple - we just need to use a few of the further simplifications that we've already seen.

# %% [markdown]
# If I remember correctly, the first thing we want to do is to slice the existing data to a dataframe that has all the information we want/need:
# 1. Find the time stamps we're looking for
# 2. Combine and convert the existing files into ones that has the following columns: annulus, grout, **CONSISTENT** time, and corresponding heat injection rates
# _Note this will be problematic because we have four-minute-intervals while the other have five-minute ones... but nonetheless this is a key step to complete, and we can call quit today once this is achieved._
# 3. Calculate $R_{b,g}$
# 4. Calculate the corresponding $k_{s,i}$ using the equation on notebook

# %% [markdown]
# ### Measurement Time
# Start - Sep, 10th, 17:40:50
#
# End - Sep, 12th, 18:10:00

# %%
#Now let's try to process these folders/file data
import matplotlib.pyplot as plt

# %%
import pandas as pd
import os
from glob import glob

# %%
ts = glob('pt0920/channel 1/2019/sep/*00001.ddf')

# %%
ts.sort()

# %%
ts[-1]>ts[0]
# Out:
# True

# %%
s1 = 'pt0920/channel 1/2019/sep/'
s2 = 'pt0920/channel 2/2019/sep/'
s3 = 'pt0920/channel 3/2019/sep/'
s4 = 'pt0920/channel 4/2019/sep/'
s0 = '*00001.ddf'
s = [s0,s1,s2,s3,s4]

# %%
import bisect
fl = []
for i in s[1:]:
    fi = glob(i+s0)
    fi.sort()
    ref1 = i + i[7:16] + ' 20190910 174000' + s0[1:]
    ref2 = i + i[7:16] + ' 20190912 181000' + s0[1:]
    fin = fi[bisect.bisect_right(fi,ref1):]
    fnn = fin[:bisect.bisect_left(fin,ref2)]
    fl.append(fnn)
    print i+s0
# Out:
# pt0920/channel 1/2019/sep/*00001.ddf
# pt0920/channel 2/2019/sep/*00001.ddf
# pt0920/channel 3/2019/sep/*00001.ddf
# pt0920/channel 4/2019/sep/*00001.ddf

# %% [markdown]
# So, good news is we now have fl as the names of the files that we want to harvest, so we do have things in order. Now that's assemble the csvs together.
#
# Note that Channel 1, 3 are inner duplicates, 2,4 are outer duplicates.

# %%
for i in range(4):
    print len(fl[i])
    
#We're working only C3 and C4 for now since they happen to ...! have consistent lengths.
# Out:
# 715
# 696
# 686
# 691

# %%
import pickle
with open('ins','rb') as f:
    inss = pickle.load(f)
insf = ['%.3f' % elem for elem in inss]

# %%
f23 = fl[2]
all3 = pd.DataFrame()
for i in range(len(f23)):
    fram = pd.read_csv(f23[i],header=25,sep='\t')
    fram.set_axis(['depth','tempc','stokes','nonstokes'],axis=1,inplace=True)
    DF = fram[fram['depth']>0]
    DF = DF.set_index('depth')
    DF = DF.transpose()
    s = DF.iloc[0].astype(float)
    s.name = str(f23[i])[-25:-25+8]+str(f23[i])[-25+9:-25+15]
#     print s
    all3 = all3.append(s)

# %%
f24 = fl[3]
all4 = pd.DataFrame()
for i in range(len(f24)):
    fram = pd.read_csv(f24[i],header=25,sep='\t')
    fram.set_axis(['depth','tempc','stokes','nonstokes'],axis=1,inplace=True)
    DF = fram[fram['depth']>0]
    DF = DF.set_index('depth')
    DF = DF.transpose()
    s = DF.iloc[0].astype(float)
    s.name = str(f24[i])[-25:-25+8]+str(f24[i])[-25+9:-25+15]
#     print s
    all4 = all4.append(s)

# %%
all3.describe()
# Out:
#           0.556       1.571       2.586       3.600       4.615       5.629    \
# count  686.000000  686.000000  686.000000  686.000000  686.000000  686.000000
# mean    34.178595   31.314465   27.825373   26.130101   24.631875   20.824929
# std      5.232315    5.259066    5.102314    4.937556    4.642868    3.692393
# min     26.679000   23.868000   20.558000   19.064000   18.042000   15.589000
# 25%     29.683000   26.714500   23.193000   21.574750   20.455500   17.622750
# 50%     33.662000   30.857000   27.599500   25.912000   24.488500   20.750000
# 75%     38.365250   35.400500   31.402750   29.519750   27.698000   22.954000
# max     55.454000   52.672000   49.517000   47.790000   45.919000   41.231000
#
#           6.644       7.659       8.673       9.688    ...     413.496  \
# count  686.000000  686.000000  686.000000  686.000000  ...  686.000000
# mean    10.591738    2.478055    1.298657    1.089520  ...   25.939061
# std      2.359654    1.795329    1.782961    1.763852  ...    3.103324
# min      7.399000    0.676000   -0.290000   -0.449000  ...   18.426000
# 25%      8.586000    1.117500   -0.047500   -0.225000  ...   23.638500
# 50%     10.898500    2.756500    1.400000    1.141000  ...   26.453000
# 75%     11.686000    3.295250    2.218500    1.959500  ...   28.109000
# max     29.868000   21.246000   20.091000   19.909000  ...   48.443000
#
#           414.511     415.526     416.540     417.555     418.569     419.584  \
# count  686.000000  686.000000  686.000000  686.000000  686.000000  686.000000
# mean    26.026118   26.030741   26.005806   25.946321   25.680781   25.619424
# std      3.111285    3.111018    3.108597    3.102379    3.099326    3.100759
# min     18.397000   18.213000   18.340000   18.194000   17.978000   18.067000
# 25%     23.769750   23.751750   23.706500   23.628750   23.368000   23.328000
# 50%     26.532000   26.558500   26.496000   26.428500   26.235000   26.129500
# 75%     28.205500   28.199250   28.168750   28.117250   27.847000   27.798250
# max     48.457000   48.570000   48.565000   48.470000   48.109000   48.021000
#
#           420.599     421.613     422.628
# count  686.000000  686.000000  686.000000
# mean    25.707633  124.672972  107.514729
# std      3.103864   28.160610   24.739205
# min     18.192000   82.851000   70.174000
# 25%     23.396250  101.249500   87.175750
# 50%     26.238000  110.792000   95.556500
# 75%     27.878750  156.770000  135.513250
# max     48.239000  206.913000  181.287000
#
# [8 rows x 417 columns]

# %%
all4.describe()
# Out:
#           0.556       1.571       2.586       3.600       4.615       5.629    \
# count  691.000000  691.000000  691.000000  691.000000  691.000000  691.000000
# mean    34.117750   29.991329   25.992732   24.904197   24.277463   18.326890
# std      5.228377    5.178482    4.948807    4.771881    4.441682    3.346299
# min     26.618000   22.554000   18.820000   17.920000   17.773000   13.607000
# 25%     29.636000   25.417000   21.548000   20.509000   20.252500   15.500500
# 50%     33.609000   29.664000   25.854000   24.781000   24.129000   18.370000
# 75%     38.171000   33.929000   29.561500   28.272500   27.244000   20.345000
# max     55.493000   51.268000   47.035000   45.844000   44.901000   37.968000
#
#           6.644       7.659       8.673       9.688    ...     413.496  \
# count  691.000000  691.000000  691.000000  691.000000  ...  691.000000
# mean     7.363437    1.655615    1.181797    1.125069  ...   27.443333
# std      2.042650    1.708030    1.705572    1.706280  ...    3.118467
# min      4.764000    0.056000   -0.353000   -0.421000  ...   19.613000
# 25%      5.737500    0.299500   -0.176000   -0.222500  ...   25.150000
# 50%      7.843000    1.924000    1.282000    1.189000  ...   28.022000
# 75%      8.452500    2.514500    2.047000    2.006000  ...   29.625000
# max     26.122000   20.389000   20.007000   19.861000  ...   49.986000
#
#           414.511     415.526     416.540     417.555     418.569     419.584  \
# count  691.000000  691.000000  691.000000  691.000000  691.000000  691.000000
# mean    27.441618   27.465220   27.462609   27.463016   27.461728   27.470784
# std      3.122902    3.118113    3.116252    3.122480    3.121426    3.117546
# min     19.578000   19.623000   19.644000   19.681000   19.653000   19.651000
# 25%     25.192500   25.180000   25.166500   25.145500   25.182000   25.193500
# 50%     27.993000   28.021000   28.019000   27.997000   27.992000   28.002000
# 75%     29.613000   29.629000   29.656000   29.638000   29.658000   29.668500
# max     50.054000   49.991000   50.030000   49.975000   50.049000   49.965000
#
#           420.599     421.613     422.628
# count  691.000000  691.000000  691.000000
# mean    27.495887  108.324543  107.038588
# std      3.122312   25.990536   24.396063
# min     19.613000   68.948000   69.651000
# 25%     25.201000   87.960000   88.121000
# 50%     27.993000   95.310000   94.827000
# 75%     29.682500  137.908000  134.519500
# max     50.104000  183.834000  180.355000
#
# [8 rows x 417 columns]

# %%
all3['DT'] = pd.to_datetime(all3.index.values)
all4['DT'] = pd.to_datetime(all4.index.values)

# %%
all3 = all3.set_index('DT')
all4 = all4.set_index('DT')

# %%
all3.index[0]
# Out:
# Timestamp('2019-09-10 17:42:10')

# %%
#This was done manually to calculate the differences in hours
begin = pd.to_datetime('20190910174000')
end = pd.to_datetime('20190912181000')

# %%
import numpy as np
all3['hrs'] = all3.index - begin
all3['hrs'] = all3['hrs']/np.timedelta64(1,'h')
all4['hrs'] = all4.index - begin
all4['hrs'] = all4['hrs']/np.timedelta64(1,'h')

# %% [markdown]
# How about we try to just estimate the heat injection rate using the iterative approach here so that we get the heat injection rate at any given point? Should be possible.

# %%
xls = pd.read_excel('gtri_raw.xlsx',index_col=0,skiprows=3)
xls = xls.rename(columns={xls.columns[-1]:'HeatIn'})
gtri = xls[['Supply1','Return1','HeatIn','(hr)']].copy()
yinterp = np.interp(gtri['(hr)'],gtri['(hr)'],gtri['HeatIn'])

# %%
np.interp(10,gtri['(hr)'],gtri['HeatIn'])
# Out:
# 78.13022400461705

# %%
#Remember Hin here is already Q over L!!!
all3['Hin'] = np.interp(all3['hrs'],gtri['(hr)'],gtri['HeatIn'])
all4['Hin'] = np.interp(all4['hrs'],gtri['(hr)'],gtri['HeatIn'])

# %%
#Let's operate and get a new all4 that has a displaced distance set: 
reali = all4.columns[:-2].values.astype(float)-1.5
alt4 = all4.copy()
for k in all4.index:
    yinterp = np.interp(all4.columns[:-2].values.astype(float),all4.loc[k][:-2],reali)
    alt4.loc[k][:-2] = yinterp

# %%
temps = all4.iloc[200][:-4].values 
index = all4.iloc[200][:-4].index.values.astype(float)

# %%
fig = plt.figure(figsize=(13,5))
plt.plot(index,np.interp(index,index-1.5,temps),label='NEW')
plt.plot(index,temps,label = 'old')
plt.legend()

# %%
can = all4[all4.columns[:-2]].iloc[:5]
for i in can.index:
#     print can.loc[i]
    can.loc[i] = c15(can.loc[i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-974669f43b22> in <module>()
#       2 for i in can.index:
#       3 #     print can.loc[i]
# ----> 4     can.loc[i] = c15(can.loc[i])
#
# NameError: name 'c15' is not defined

# %%
can.iloc[0][:-4].plot()
can.iloc[1][:-4].plot()
can.iloc[2][:-4].plot()

# %%
#Make a copy of old all4
oall4 = all4.copy()
testal4['hrs'] = all4['hrs']
testal4['Hin'] = all4['Hin']

# %%
def c15(ps):
    filt = ps
    temps= filt.values
    index= filt.index.values.astype(float)
    in5 = index - 1.5
    nt = np.interp(index,in5,temps)
    return nt

# %%
all3.Hin.plot()
all4.Hin.plot()

# %%
#Try to remove outlier
all3 = all3[all3[all3.columns[4]] <40]

# %%
all3[all3.columns[4::70]].plot(figsize=(10,6))

# %%
import matplotlib.pyplot as plt

# %%
all3[all3.columns[0]].plot(figsize=(10,5),label='INSIDE')
all4[all4.columns[0]].plot(label='OUTSIDE')
plt.ylim(34,35)
plt.legend()

# %%
all3.to_csv('C3proc.csv')
all4.to_csv('C4proc.csv')

# %%
all3 = pd.read_csv('C3proc.csv',index_col=0)
all4 = pd.read_csv('C4proc.csv',index_col=0)

# %%
AL = all3[all3['hrs']>14]

# %%
AL[AL.columns[4::70]].plot(figsize=(10,8))

# %%
all3.columns[5::60]
# Out:
# Index([u'5.629', u'66.505', u'127.381', u'188.25599999999997', u'249.132',
#        u'310.008', u'370.88300000000004'],
#       dtype='object')

# %%
all3.hrs.head(5)
# Out:
# DT
# 2019-09-10 17:42:10    0.036111
# 2019-09-10 17:46:11    0.103056
# 2019-09-10 17:50:11    0.169722
# 2019-09-10 17:54:11    0.236389
# 2019-09-10 17:58:11    0.303056
# Name: hrs, dtype: float64

# %%
all4.hrs.head(5)
# Out:
# DT
# 2019-09-10 17:43:11    0.053056
# 2019-09-10 17:47:11    0.119722
# 2019-09-10 17:51:11    0.186389
# 2019-09-10 17:55:11    0.253056
# 2019-09-10 17:59:11    0.319722
# Name: hrs, dtype: float64

# %% [markdown]
# Let's switch gear a little bit - to avoid the iteration problem, don't try to hard with the time steps since they simply aren't consistent. Let's try to only use the hours beyond 10 and get the mean values of all3 and all4, and then we can do the calculation easy.

# %%
al3_10=all3[all3['hrs']>10]
al4_10=all4[all4['hrs']>10]

# %%
al3a = al3_10.mean()
al4a = al4_10.mean()

# %%
al3_10.describe()
# Out:
#             0.556       1.571  2.5860000000000003         3.6       4.615  \
# count  532.000000  532.000000          532.000000  532.000000  532.000000
# mean    35.529820   32.729242           29.263821   27.553252   25.961553
# std      4.554787    4.528827            4.286747    4.080359    3.806924
# min     26.858000   23.982000           20.743000   19.248000   18.154000
# 25%     32.629750   29.839750           26.745250   25.304750   23.897750
# 50%     35.007500   32.024000           28.623000   26.880000   25.400000
# 75%     39.893500   37.068750           33.134000   31.209000   29.218000
# max     43.426000   40.797000           36.975000   34.957000   32.705000
#
#             5.629       6.644       7.659       8.673  9.687999999999999  ...  \
# count  532.000000  532.000000  532.000000  532.000000         532.000000  ...
# mean    21.839417   11.155923    2.782534    1.569558           1.345789  ...
# std      2.909424    1.533890    0.924314    0.946393           0.921982  ...
# min     16.048000    8.004000    0.938000   -0.245000          -0.362000  ...
# 25%     20.244250   10.125250    1.954500    0.498750           0.274000  ...
# 50%     21.645500   11.297500    2.968500    1.823000           1.634000  ...
# 75%     24.129250   12.253250    3.383750    2.294000           2.063500  ...
# max     27.166000   13.911000    5.714000    4.093000           3.876000  ...
#
#           415.526      416.54     417.555     418.569     419.584     420.599  \
# count  532.000000  532.000000  532.000000  532.000000  532.000000  532.000000
# mean    26.986568   26.956840   26.896453   26.633226   26.572910   26.658966
# std      1.734333    1.729839    1.729447    1.729293    1.721374    1.728659
# min     23.418000   23.368000   23.351000   23.022000   23.033000   23.076000
# 25%     25.251500   25.233000   25.193000   24.922500   24.839750   24.965000
# 50%     27.827000   27.760500   27.760500   27.473000   27.360000   27.484500
# 75%     28.336250   28.272250   28.231750   27.969000   27.904500   27.990250
# max     29.788000   29.724000   29.875000   29.586000   29.365000   29.429000
#
#        421.61300000000006  422.62800000000004         hrs         Hin
# count          532.000000          532.000000  532.000000  529.000000
# mean           114.895801           99.008895   28.877921   77.841009
# std             24.041966           21.244364   11.085419    0.121268
# min             82.851000           70.174000   10.036111   77.659232
# 25%             96.615500           83.090750   19.153056   77.759186
# 50%            108.859000           93.775000   29.003056   77.816027
# 75%            113.058500           97.402250   37.852986   77.869743
# max            161.810000          140.644000   48.484444   78.138135
#
# [8 rows x 419 columns]

# %%
vT = (al4a-al3a).iloc[:-6]

# %%
vT.plot()

# %% [markdown]
# So we have the temperature differencial here... Or so I think. The only problem now is how to advance this into the thermal conductivity. I believe we have a rough idea. This involves using the following relationship:
#
#
# $$4\pi\sum^N_{i=1} k_{s,i}m_i l_i = \sum^N_{i=1}q_i = \sum^N_{i=1}\frac{\delta T_i}{R_i} = \frac{\sum^N_{i=1}(T_{an,i}-T_{b,i})}{R_g+R_{conv}+R_{cond}} = Q$$
#
# This shoud apply to any given time step.

# %% [markdown]
# Now here are some known parameters:
#
# $k_g = 2.77 W/m\cdot K$
#
# $k_{ep} = 22.5 W/m\cdot K$
#
# $d_{eo} = 0.1651 m = 2r_b$
#
# $Len = 408.43 m$
#
# $R_g = \frac{ln(\frac{d_{eo}+ 0.004)}{d_{eo}})}{2\pi k_g}$ + $\frac{ln(\frac{d_{eo})}{d_{ei}})}{2\pi k_{ep}}$ + $\frac{1}{\pi d_{ei}h_{po}}$
#
# _If necessary: This could also be calculated for any flow rate_

# %% [markdown]
# We now mostly just want to convert testv.py to something that we can easily get the hpo and Rg out of using any given deo, dei, Len and flow rates. This should be easy. The next step would therefore be casually converting the strin series with their index values (depths) into what we already know to be correct...
#
# It's important to stress this again: **$m$ is the gradient of temperature over natural log of time in hours**.

# %%
import numpy as np

# %%
def mfdf10(df):
#     df = df[df['hrs']>10]
#     all3[all3['hrs']>10]
    tar = df.set_index('hrs')
    tcol= tar.columns[:-1]
    dt = pd.DataFrame(columns = tcol)
    for i in tcol:
        dt[i]= np.gradient(tar.iloc[:-1][i],np.log(tar.iloc[:-1].index.values.astype(float)))
    return dt
def mmf(df):
    mdf = mfdf10(df)
    return mdf.mean()

# %%
msms = mfdf10(all3)

# %%
def gtG(df):
    DF = pd.DataFrame()
    for i in df.columns:
        DF[i]= np.gradient(df[i],np.log(df.index.values.astype(float)))
    return DF

# %%
plt.plot(np.log(all3.hrs),all3[all3.columns[410]])

# %%
gt = all3[all3.columns[410]]

# %%
gt[gt<45].plot(marker = 'o',linestyle='')

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_re = LinearRegression()
X = np.log(all3.hrs).values.reshape(-1,1)
Y = all3[all3.columns[410]].values.reshape(-1,1)
linear_re.fit(X,Y)
Y_pred = linear_re.predict(X)

# %%
# plt.scatter(X,Y)
plt.plot(X[X>0].reshape(-1,1),linear_re.predict(X[X>0].reshape(-1,1)),color='red')

# %%
(linear_re.predict(X[X>0].reshape(-1,1))[-1]- linear_re.predict(X[X>0].reshape(-1,1))[0])/(X[X>0][-1]-X[X>0][0])
# Out:
# array([2.42308515])

# %%
linear_re.coef_
# Out:
# array([[2.42308515]])

# %%
def getMMS(df):
    sr = np.array([])
    X = np.log(df.hrs.values).reshape(-1,1)
    for i in range(len(df.columns)-3):
        lnr = LinearRegression()
#         X = np.log(all3.hrs).values.reshape(-1,1)
        Y = df[df.columns[i]].values.reshape(-1,1)
        lnr.fit(X,Y)
#         try:
#             print lnr.coef_
#         except:
#             continue
        sr = np.append(sr,lnr.coef_[0][0])
    return sr

# %%
all4=all4[all4.hrs>10]

# %%
# len(getMMS(all3))
fig = plt.figure(figsize=(12,5))
plt.plot(all3.columns[:-4],getMMS(all3)[:-1],label='Annulus')
plt.plot(all4.columns[:-4],getMMS(all4)[:-1],label='Grout')

plt.ylabel('m = ($\Delta T$/ln(Time))')
plt.xlabel('Distance from ground surface (m)')
plt.title('m-Value variation with respect to elevation of borehole averaged beyond 10th hour')
plt.margins(x=0)
plt.legend()
plt.tight_layout()
plt.savefig('mvar.png',dpi = 250)

# %%
all3.shape
# Out:
# (536, 419)

# %%
for i in range(419-4):
    all3 = all3[all3['hrs']>10]
    lnr = LinearRegression()
    X = np.log(all3.hrs).values.reshape(-1,1)
    Y = all3[all3.columns[i]].values.reshape(-1,1)
    try:
        print lnr.fit(X,Y).coef_
    except:
        continue
# Out:
# [[3.79714342]]
# [[3.46857459]]
# [[3.05378421]]
# [[2.79181753]]
# [[2.61579929]]
# [[1.98008138]]
# [[1.46387007]]
# [[1.484154]]
# [[1.59821788]]
# [[1.54002436]]
# [[1.48184265]]
# [[1.45486666]]
# [[1.16705583]]
# [[1.44645829]]
# [[2.57926881]]
# [[3.15650778]]
# [[3.24961379]]
# [[3.26867535]]
# [[3.26960325]]
# [[3.27327029]]
# [[3.30116458]]
# [[3.3286423]]
# [[3.3454342]]
# [[3.31640231]]
# [[3.33800073]]
# [[3.3185119]]
# [[3.32799828]]
# [[3.30534686]]
# [[3.3208717]]
# [[3.30395923]]
# [[3.32241717]]
# [[3.3154374]]
# [[3.33459816]]
# [[3.3398507]]
# [[3.32357508]]
# [[3.29648629]]
# [[3.30295318]]
# [[3.27367964]]
# [[3.30902773]]
# [[3.29816599]]
# [[3.30102603]]
# [[3.28799291]]
# [[3.27201056]]
# [[3.26497954]]
# [[3.25602516]]
# [[3.27043427]]
# [[3.28345621]]
# [[3.31231449]]
# [[3.32288679]]
# [[3.30925022]]
# [[3.31662072]]
# [[3.32565553]]
# [[3.3342801]]
# [[3.31675662]]
# [[3.30565819]]
# [[3.28678724]]
# [[3.2919113]]
# [[3.27806465]]
# [[3.25396299]]
# [[3.25990245]]
# [[3.27279307]]
# [[3.26895469]]
# [[3.26000831]]
# [[3.25460102]]
# [[3.24192837]]
# [[3.2366752]]
# [[3.24669803]]
# [[3.2539384]]
# [[3.25727725]]
# [[3.24314514]]
# [[3.23432881]]
# [[3.21726574]]
# [[3.21687734]]
# [[3.19423258]]
# [[3.21105365]]
# [[3.22507696]]
# [[3.23488348]]
# [[3.2224443]]
# [[3.22884673]]
# [[3.22279658]]
# [[3.24893032]]
# [[3.25554449]]
# [[3.26127159]]
# [[3.28294989]]
# [[3.32762442]]
# [[3.34352481]]
# [[3.34558345]]
# [[3.3239053]]
# [[3.31861712]]
# [[3.31327464]]
# [[3.33194448]]
# [[3.3237868]]
# [[3.32282945]]
# [[3.29951944]]
# [[3.31600278]]
# [[3.31503496]]
# [[3.31364874]]
# [[3.29633854]]
# [[3.31018876]]
# [[3.32599206]]
# [[3.32293693]]
# [[3.31422253]]
# [[3.3127138]]
# [[3.34418515]]
# [[3.32295705]]
# [[3.28840522]]
# [[3.26182676]]
# [[3.25403728]]
# [[3.25654979]]
# [[3.22695662]]
# [[3.22522605]]
# [[3.21394332]]
# [[3.26541423]]
# [[3.2787031]]
# [[3.27877255]]
# [[3.2435621]]
# [[3.24159852]]
# [[3.24743114]]
# [[3.23777332]]
# [[3.21773309]]
# [[3.22230251]]
# [[3.19785795]]
# [[3.19781129]]
# [[3.17825065]]
# [[3.17960167]]
# [[3.1730496]]
# [[3.17921712]]
# [[3.20957943]]
# [[3.21985899]]
# [[3.22700944]]
# [[3.26645505]]
# [[3.26377249]]
# [[3.25697181]]
# [[3.27138464]]
# [[3.2784307]]
# [[3.26985568]]
# [[3.27873768]]
# [[3.27926081]]
# [[3.28379256]]
# [[3.28023668]]
# [[3.32061797]]
# [[3.31997214]]
# [[3.31501155]]
# [[3.30542076]]
# [[3.32054444]]
# [[3.28602367]]
# [[3.28311624]]
# [[3.26661673]]
# [[3.26321824]]
# [[3.2447307]]
# [[3.24423644]]
# [[3.24457257]]
# [[3.27288599]]
# [[3.26022441]]
# [[3.29117215]]
# [[3.27386295]]
# [[3.28214035]]
# [[3.27530349]]
# [[3.31061209]]
# [[3.31795725]]
# [[3.26641156]]
# [[3.24653599]]
# [[3.26270781]]
# [[3.24335548]]
# [[3.26456504]]
# [[3.26818426]]
# [[3.29687948]]
# [[3.26642429]]
# [[3.25522289]]
# [[3.2496019]]
# [[3.29720261]]
# [[3.31057333]]
# [[3.30172124]]
# [[3.2595027]]
# [[3.23782021]]
# [[3.25330357]]
# [[3.27143805]]
# [[3.24846458]]
# [[3.23386716]]
# [[3.26129099]]
# [[3.26624322]]
# [[3.28069849]]
# [[3.28543633]]
# [[3.27141338]]
# [[3.25992874]]
# [[3.27116096]]
# [[3.27988467]]
# [[3.29663881]]
# [[3.28698976]]
# [[3.20086841]]
# [[3.12029809]]
# [[3.0961104]]
# [[3.14282814]]
# [[3.21918065]]
# [[3.26415356]]
# [[3.26942748]]
# [[3.31635537]]
# [[3.30874302]]
# [[3.33174423]]
# [[3.32744114]]
# [[3.33323233]]
# [[3.33378607]]
# [[3.29668282]]
# [[3.22501543]]
# [[3.24836944]]
# [[3.25213936]]
# [[3.25634301]]
# [[3.27567621]]
# [[3.26897116]]
# [[3.27558952]]
# [[3.3186428]]
# [[3.3042635]]
# [[3.277151]]
# [[3.2627548]]
# [[3.28285625]]
# [[3.29402898]]
# [[3.30283923]]
# [[3.29895862]]
# [[3.28299114]]
# [[3.26955388]]
# [[3.27171233]]
# [[3.28071764]]
# [[3.29931628]]
# [[3.29354848]]
# [[3.29207132]]
# [[3.26541433]]
# [[3.23185766]]
# [[3.22592312]]
# [[3.26087684]]
# [[3.22961348]]
# [[3.22638541]]
# [[3.24606929]]
# [[3.2188604]]
# [[3.2127974]]
# [[3.21518084]]
# [[3.20811922]]
# [[3.20785591]]
# [[3.20832476]]
# [[3.23747776]]
# [[3.21728859]]
# [[3.25439076]]
# [[3.2475215]]
# [[3.25655594]]
# [[3.26816974]]
# [[3.28180387]]
# [[3.27452444]]
# [[3.29784985]]
# [[3.33756074]]
# [[3.3545207]]
# [[3.3325644]]
# [[3.32571907]]
# [[3.34214827]]
# [[3.33960332]]
# [[3.32260109]]
# [[3.33936342]]
# [[3.30829493]]
# [[3.31680127]]
# [[3.30670819]]
# [[3.33448945]]
# [[3.33665556]]
# [[3.36416459]]
# [[3.38096484]]
# [[3.34861684]]
# [[3.32094256]]
# [[3.31573713]]
# [[3.29277209]]
# [[3.297801]]
# [[3.29039258]]
# [[3.28079321]]
# [[3.27810915]]
# [[3.27510083]]
# [[3.28402935]]
# [[3.29090677]]
# [[3.27456662]]
# [[3.27696755]]
# [[3.2866544]]
# [[3.31908634]]
# [[3.31675612]]
# [[3.30988976]]
# [[3.27526014]]
# [[3.23636468]]
# [[3.25621635]]
# [[3.26643239]]
# [[3.2684444]]
# [[3.28266929]]
# [[3.26850868]]
# [[3.26523801]]
# [[3.25815244]]
# [[3.27493942]]
# [[3.25367524]]
# [[3.2752386]]
# [[3.28958008]]
# [[3.29689394]]
# [[3.26718676]]
# [[3.27477407]]
# [[3.26574167]]
# [[3.26967342]]
# [[3.28428988]]
# [[3.31196298]]
# [[3.32198509]]
# [[3.32664324]]
# [[3.3255096]]
# [[3.33160751]]
# [[3.29947136]]
# [[3.27024119]]
# [[3.28126387]]
# [[3.31696963]]
# [[3.30977864]]
# [[3.28519193]]
# [[3.24444397]]
# [[3.23213276]]
# [[3.19242408]]
# [[3.18971976]]
# [[3.22265167]]
# [[3.24175313]]
# [[3.19202573]]
# [[3.16239859]]
# [[3.16407458]]
# [[3.22322081]]
# [[3.24855771]]
# [[3.25494668]]
# [[3.25080353]]
# [[3.25221438]]
# [[3.22512297]]
# [[3.23300206]]
# [[3.21325394]]
# [[3.21032031]]
# [[3.21075563]]
# [[3.25115852]]
# [[3.27732046]]
# [[3.2982344]]
# [[3.24463737]]
# [[3.27081656]]
# [[3.28682487]]
# [[3.31035257]]
# [[3.31734048]]
# [[3.33990237]]
# [[3.3221545]]
# [[3.33609521]]
# [[3.32201999]]
# [[3.32149404]]
# [[3.33016258]]
# [[3.33372298]]
# [[3.30726051]]
# [[3.30408079]]
# [[3.26839624]]
# [[3.27463686]]
# [[3.25455322]]
# [[3.27665626]]
# [[3.2644124]]
# [[3.28237223]]
# [[3.27293511]]
# [[3.24874178]]
# [[3.26336309]]
# [[3.2784215]]
# [[3.23870291]]
# [[3.27952866]]
# [[3.28061858]]
# [[3.26819262]]
# [[3.31664027]]
# [[3.3257655]]
# [[3.3431813]]
# [[3.34596077]]
# [[3.33257696]]
# [[3.32263616]]
# [[3.28750715]]
# [[3.28309363]]
# [[3.30359715]]
# [[3.31586803]]
# [[3.30736971]]
# [[3.30228734]]
# [[3.30371154]]
# [[3.32339697]]
# [[3.33278943]]
# [[3.35015092]]
# [[3.33158761]]
# [[3.30972485]]
# [[3.31552161]]
# [[3.34043152]]
# [[3.33010141]]
# [[3.31814026]]
# [[3.27017564]]
# [[3.26837138]]
# [[3.24118765]]
# [[3.25817944]]
# [[3.24415789]]
# [[3.30370552]]
# [[3.31663647]]
# [[3.27501416]]
# [[3.19960801]]
# [[3.129299]]
# [[3.09703163]]
# [[3.15887684]]
# [[3.20118385]]
# [[3.215001]]
# [[3.19599236]]
# [[3.22083935]]
# [[3.22450571]]
# [[3.2451607]]
# [[3.26785524]]
# [[3.3169151]]
# [[3.32437614]]
# [[3.33494976]]
# [[3.33870354]]
# [[3.33265634]]
# [[3.34068987]]
# [[3.3247023]]
# [[3.33456659]]
# [[3.33088659]]
# [[3.33916913]]
# [[3.32782919]]
# [[3.32894022]]
# [[3.32996281]]
# [[3.31179714]]
# [[3.3290772]]

# %%
mmf(all3).plot(label='3-Grout',figsize=(12,5))
mmf(all4).plot(label='4-Annulus')
plt.legend()
plt.title('m-Value variation with respect to elevations')
plt.savefig('avem.png')

# %%
mmf(all4).mean()
# Out:
# 2.8639498280637845

# %%
all3.columns
# Out:
# Index([  0.556,   1.571,   2.586,     3.6,   4.615,   5.629,   6.644,   7.659,
#          8.673,   9.688,
#        ...
#        415.526,  416.54, 417.555, 418.569, 419.584, 420.599, 421.613, 422.628,
#         u'hrs',  u'Hin'],
#       dtype='object', length=419)

# %% [markdown]
# Now just write a program that takes mi, li ? vT to generate ks.

# %%
vT.plot(figsize=(12,5),label='$\Delta T$')
plt.xlabel('Distance from ground surface (m)')
plt.ylabel('Temperature difference ($\degree C$)')
plt.legend()
plt.title('Temperature variation averaged during the TRT test period across borehole')
plt.tight_layout()

plt.savefig('delTave.png',dpi = 250)

# %%
ta3 = all3.transpose()
ta4 = all4.transpose()
tt4 = testal4.transpose()

# %%
ta3.columns[10],ta3.columns[650],ta4.columns[650],tt4.columns[650]
# Out:
# (Timestamp('2019-09-10 18:22:11'),
#  Timestamp('2019-09-12 15:34:11'),
#  Timestamp('2019-09-12 15:11:10'),
#  Timestamp('2019-09-12 15:11:10'))

# %%
ta3[ta3.columns[10]][:-4].plot(label='C3 - annulus -'  + str(ta3.columns[10]))
# tt4[tt4.columns[10]][:-4].plot(label='C4 -  grout -   '    + tt4.columns[10])
ta4[ta4.columns[10]][:-4].plot(label='C40 -  grout -   '    + str(ta4.columns[10]))

ta3[ta3.columns[650]][:-4].plot(label='C3 - annulus -' + str(ta3.columns[650]),figsize=(16,8))
# tt4[tt4.columns[650]][:-4].plot(label='C4 -  grout -   '+ tt4.columns[650])
ta4[ta4.columns[650]][:-4].plot(label='C40 -  grout -   '    + str(ta4.columns[10]))


plt.legend()

# %%
import testv as tv

# %%
tv.cbhe(w=0.00123).Rg
# Out:
# 0.006696492429662382

# %%
import testv as tv
def gks(dt,m,li):
    rb = tv.cbhe().Rg #Rg = 0.015 
    return dt/rb/4/np.pi/m/li

# %%
DIS0 = all3.columns.values[:-2].astype(float)

# %%
np.mean(gks(vT,mmf(all3),np.append(1e-5,np.diff(all3.columns.values[:-2].astype(float)))))
# Out:
# -1961.334364537548

# %%
len(vT)
# Out:
# 413

# %%
len(getMMS(all3)[:-3])
# Out:
# 413

# %%
len(np.append(1e-5,np.diff(all3.columns.values[:-2].astype(float))))
# Out:
# 417

# %%
kss = gks(vT,getMMS(all3)[:-3],np.append(1e-5,np.diff(all3.columns.values[:-2].astype(float)))[:-4])

# %%
def gkks(dt,m,li):
    rb = 0.0006*420
    return dt/rb/4/np.pi/m/li
ksss= gkks(vT,getMMS(all3)[:-3],1.015)

# %%
kss = kss[kss<15]
kss = kss[kss>-30]

# %%
inst = kss.index.values.astype(float)
inst = ['%.3f' % elem for elem in inst]

# %%
kss.index = inst

# %%
kss = kss/5*4

# %%
kss.describe()
# Out:
# count    412.000000
# mean       3.936132
# std        2.143502
# min      -17.844827
# 25%        3.504264
# 50%        4.011108
# 75%        4.634113
# max       11.041709
# dtype: float64

# %%
kss.plot(figsize=(12,5),label='$k_s$',color='g')
plt.xlabel('Distance from ground surface (m)')
plt.ylabel('Thermal conductivity (W/m K)')
plt.title('Thermal conductivity variation at different depths')
plt.tight_layout()
plt.savefig('ks.png',dpi = 250)

# %%
# ksss = ksss[ksss<15]
# ksss = ksss[ksss>-30]
ksss.plot()

# %%
ksss.mean()
# Out:
# 0.29866849838913645

# %%
alss = kss/2.515e6*24*3600
alss.plot()

# %%
len(kss)
# Out:
# 412

# %%
len(getMMS(all3)[:-1])
# Out:
# 415

# %%
qss = (kss*4*np.pi*getMMS(all3)[:-4])*1.015

# %%
qss.mean()
# Out:
# 121.1268159330695

# %%
qss.mean()/3.375
# Out:
# 35.8894269431317

# %%
qss.plot(figsize=(12,5),color='brown')
plt.xlabel('Distance from ground surface (m)')
plt.ylabel('Heat extraction rate, Q (W/m)')
plt.title('Average heat extraction rate beyond 50 meters: 35.88 W/ft')
plt.savefig('qss.png',dpi=250)

# %%
qss.sum()/1340
# Out:
# -43.65925366342087

# %%
alss.mean()
# Out:
# -0.1156548399743855

# %%
kss.mean()
# Out:
# -3.366573177495132

# %%
len(kss)
# Out:
# 386

# %%
np.mean(all3.mean() - all4.mean())
# Out:
# -2.1882770473664004

# %%
gks(-2.18,3.28,420.8)*420.8
# Out:
# -3.44813304895317

# %%
gks(vT,3.28,np.append(1e-5,np.diff(all3.columns.values[:-2].astype(float)))[:-2])[1:].plot(figsize=(12,6))

# %%
ks_s = gks(vT,3.28,np.append(1e-5,np.diff(all3.columns.values[:-2].astype(float)))[:-2])[1:]

# %%
ist = ks_s.index.values.astype(float)
ist = ['%.3f' % elem for elem in ist]
ks_s.index = ist

# %%
ks_s.plot(figsize=(12,6))

# %%
alss = kss/2.515e6

# %%
alss.mean()
# Out:
# -1.4363589673464433e-06

# %%
kss.sum()
# Out:
# -1900.916224414187

# %%
mmf(al3_10).mean()
# Out:
# 2.8156005559148056

# %%
mmf(al4_10).mean()
# Out:
# 2.8639498280637845

# %%
tar = al3_10inhr.transpose()

# %%
tar.columns
# Out:
# Float64Index([10.0361111111, 10.1030555556, 10.1697222222, 10.2363888889,
#               10.3027777778, 10.3697222222, 10.4363888889, 10.5030555556,
#               10.5697222222, 10.6363888889,
#               ...
#               48.1697222222, 48.2361111111, 48.3508333333, 48.3677777778,
#               48.3844444444, 48.4011111111, 48.4177777778, 48.4344444444,
#               48.4511111111, 48.4844444444],
#              dtype='float64', name=u'hrs', length=532)

# %%
Hongshan Guotar.index.values[:-1].astype(float)
# Out:
# array([  0.556,   1.571,   2.586,   3.6  ,   4.615,   5.629,   6.644,
#          7.659,   8.673,   9.688,  10.702,  11.717,  12.731,  13.746,
#         14.761,  15.775,  16.79 ,  17.804,  18.819,  19.834,  20.848,
#         21.863,  22.877,  23.892,  24.907,  25.921,  26.936,  27.95 ,
#         28.965,  29.98 ,  30.994,  32.009,  33.023,  34.038,  35.053,
#         36.067,  37.082,  38.096,  39.111,  40.126,  41.14 ,  42.155,
#         43.169,  44.184,  45.199,  46.213,  47.228,  48.242,  49.257,
#         50.271,  51.286,  52.301,  53.315,  54.33 ,  55.344,  56.359,
#         57.374,  58.388,  59.403,  60.417,  61.432,  62.447,  63.461,
#         64.476,  65.49 ,  66.505,  67.52 ,  68.534,  69.549,  70.563,
#         71.578,  72.593,  73.607,  74.622,  75.636,  76.651,  77.666,
#         78.68 ,  79.695,  80.709,  81.724,  82.739,  83.753,  84.768,
#         85.782,  86.797,  87.812,  88.826,  89.841,  90.855,  91.87 ,
#         92.884,  93.899,  94.914,  95.928,  96.943,  97.957,  98.972,
#         99.987, 101.001, 102.016, 103.03 , 104.045, 105.06 , 106.074,
#        107.089, 108.103, 109.118, 110.133, 111.147, 112.162, 113.176,
#        114.191, 115.206, 116.22 , 117.235, 118.249, 119.264, 120.279,
#        121.293, 122.308, 123.322, 124.337, 125.352, 126.366, 127.381,
#        128.395, 129.41 , 130.424, 131.439, 132.454, 133.468, 134.483,
#        135.497, 136.512, 137.527, 138.541, 139.556, 140.57 , 141.585,
#        142.6  , 143.614, 144.629, 145.643, 146.658, 147.673, 148.687,
#        149.702, 150.716, 151.731, 152.746, 153.76 , 154.775, 155.789,
#        156.804, 157.819, 158.833, 159.848, 160.862, 161.877, 162.892,
#        163.906, 164.921, 165.935, 166.95 , 167.964, 168.979, 169.994,
#        171.008, 172.023, 173.037, 174.052, 175.067, 176.081, 177.096,
#        178.11 , 179.125, 180.14 , 181.154, 182.169, 183.183, 184.198,
#        185.213, 186.227, 187.242, 188.256, 189.271, 190.286, 191.3  ,
#        192.315, 193.329, 194.344, 195.359, 196.373, 197.388, 198.402,
#        199.417, 200.432, 201.446, 202.461, 203.475, 204.49 , 205.504,
#        206.519, 207.534, 208.548, 209.563, 210.577, 211.592, 212.607,
#        213.621, 214.636, 215.65 , 216.665, 217.68 , 218.694, 219.709,
#        220.723, 221.738, 222.753, 223.767, 224.782, 225.796, 226.811,
#        227.826, 228.84 , 229.855, 230.869, 231.884, 232.899, 233.913,
#        234.928, 235.942, 236.957, 237.972, 238.986, 240.001, 241.015,
#        242.03 , 243.045, 244.059, 245.074, 246.088, 247.103, 248.117,
#        249.132, 250.147, 251.161, 252.176, 253.19 , 254.205, 255.22 ,
#        256.234, 257.249, 258.263, 259.278, 260.293, 261.307, 262.322,
#        263.336, 264.351, 265.366, 266.38 , 267.395, 268.409, 269.424,
#        270.439, 271.453, 272.468, 273.482, 274.497, 275.512, 276.526,
#        277.541, 278.555, 279.57 , 280.585, 281.599, 282.614, 283.628,
#        284.643, 285.657, 286.672, 287.687, 288.701, 289.716, 290.73 ,
#        291.745, 292.76 , 293.774, 294.789, 295.803, 296.818, 297.833,
#        298.847, 299.862, 300.876, 301.891, 302.906, 303.92 , 304.935,
#        305.949, 306.964, 307.979, 308.993, 310.008, 311.022, 312.037,
#        313.052, 314.066, 315.081, 316.095, 317.11 , 318.125, 319.139,
#        320.154, 321.168, 322.183, 323.197, 324.212, 325.227, 326.241,
#        327.256, 328.27 , 329.285, 330.3  , 331.314, 332.329, 333.343,
#        334.358, 335.373, 336.387, 337.402, 338.416, 339.431, 340.446,
#        341.46 , 342.475, 343.489, 344.504, 345.519, 346.533, 347.548,
#        348.562, 349.577, 350.592, 351.606, 352.621, 353.635, 354.65 ,
#        355.665, 356.679, 357.694, 358.708, 359.723, 360.738, 361.752,
#        362.767, 363.781, 364.796, 365.81 , 366.825, 367.84 , 368.854,
#        369.869, 370.883, 371.898, 372.913, 373.927, 374.942, 375.956,
#        376.971, 377.986, 379.   , 380.015, 381.029, 382.044, 383.059,
#        384.073, 385.088, 386.102, 387.117, 388.132, 389.146, 390.161,
#        391.175, 392.19 , 393.205, 394.219, 395.234, 396.248, 397.263,
#        398.278, 399.292, 400.307, 401.321, 402.336, 403.35 , 404.365,
#        405.38 , 406.394, 407.409, 408.423, 409.438, 410.453, 411.467,
#        412.482, 413.496, 414.511, 415.526, 416.54 , 417.555, 418.569,
#        419.584, 420.599, 421.613, 422.628])

# %%
tar.head(5)
# Out:
# hrs                 10.036111  10.103056  10.169722  10.236389  10.302778  \
# 0.556                  27.206     27.145     27.162     27.145     27.160
# 1.571                  24.361     24.441     24.368     24.276     24.361
# 2.5860000000000003     21.131     21.191     21.047     21.124     21.131
# 3.6                    19.846     19.629     19.562     19.678     19.638
# 4.615                  18.589     18.684     18.592     18.580     18.484
#
# hrs                 10.369722  10.436389  10.503056  10.569722  10.636389  \
# 0.556                  27.252     27.235     27.038     27.244     27.231
# 1.571                  24.446     24.363     24.294     24.323     24.288
# 2.5860000000000003     21.160     21.027     21.062     21.110     20.960
# 3.6                    19.686     19.601     19.561     19.622     19.633
# 4.615                  18.570     18.398     18.510     18.634     18.535
#
# hrs                 ...  48.169722  48.236111  48.350833  48.367778  \
# 0.556               ...     34.973     34.725     34.973     34.738
# 1.571               ...     31.581     31.476     31.253     31.793
# 2.5860000000000003  ...     27.735     27.608     27.601     27.429
# 3.6                 ...     25.729     25.705     25.803     25.675
# 4.615               ...     24.272     24.268     24.159     24.347
#
# hrs                 48.384444  48.401111  48.417778  48.434444  48.451111  \
# 0.556                  34.605     34.748     34.766     34.487     34.424
# 1.571                  31.235     31.462     31.586     31.400     31.146
# 2.5860000000000003     27.412     27.454     27.769     27.705     27.242
# 3.6                    25.596     25.510     26.049     25.788     25.832
# 4.615                  24.084     24.123     24.395     24.499     24.305
#
# hrs                 48.484444
# 0.556                  34.717
# 1.571                  31.315
# 2.5860000000000003     27.672
# 3.6                    25.646
# 4.615                  24.288
#
# [5 rows x 532 columns]

# %%
def mfbh10(df):
    dfinhr = df.set_index('hrs')
    dfT = dfinhr.transpose()
    dft = dfT.drop('Hin')
#     dft['hr'] = dft.index.values.astype(float)
    print np.gradient(dft.mean(),np.log(dft.index.values.astype(float)))
    return dft

# %%
warrant = mfbh10(al3_10).index.valuesGuo

# %%
np.array(map(float,warrant))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-e4d77b9f8a73> in <module>()
# ----> 1 np.array(map(float,warrant))
#
# ValueError: could not convert string to float: Hin

# %%
Guograd1 = np.gradient(al3_10)

# %%
df = pd.read_csv(f23[0],header=25,sep='\t')
df.set_axis(['depth','tempc','stokes','nonstokes'],axis=1,inplace=True

# %%
DF = df[df['depth']>0]
DF = DF.set_index('depth')
DF = DF.transpose()

# %%
DF.append(DF.loc['tempc'])
# Out:
# depth       0.556     1.571     2.586     3.600     4.615     5.629    \
# tempc        35.028    31.922    27.816    25.583    23.846    20.057
# stokes     1511.683  1482.592  1417.013  1330.393  1282.809  1224.095
# nonstokes  1326.245  1279.463  1195.928  1108.970  1058.872   988.736
# tempc        35.028    31.922    27.816    25.583    23.846    20.057
#
# depth       6.644     7.659     8.673     9.688    ...  413.496  414.511  \
# tempc         9.562     1.082    -0.043    -0.307  ...   18.426   18.397
# stokes     1132.814  1086.536  1080.632  1077.299  ...  798.622  798.540
# nonstokes   859.212   780.507   770.431   766.641  ...  616.650  616.426
# tempc         9.562     1.082    -0.043    -0.307  ...   18.426   18.397
#
# depth      415.526  416.540  417.555  418.569  419.584  420.599   421.613  \
# tempc       18.213   18.340   18.194   17.978   18.067   18.243   150.779
# stokes     798.468  797.638  797.397  796.318  795.635  795.057  1355.958
# nonstokes  615.654  615.416  614.651  612.991  612.728  612.861  1779.870
# tempc       18.213   18.340   18.194   17.978   18.067   18.243   150.779
#
# depth       422.628
# tempc       130.645
# stokes     1437.682
# nonstokes  1779.996
# tempc       130.645
#
# [4 rows x 417 columns]

# %%
f24 = fl[3]
all4 = pd.DataFrame(index=pd.read_csv(f24[1],header=25,sep='\t')['length (m)'].values)

for i in range(len(f24)):
    fram = pd.read_csv(f24[i],header=25,sep='\t')
    fram.set_axis(['depth','tempc','stokes','nonstokes'],axis=1,inplace=True)
    all4[str(f24[i])[-25:-25+8]+str(f24[i])[-25+9:-25+15]]=fram.tempc.values

# %%
C3 = all3[all3.index.values > 0]
C4 = all4[all4.index.values > 0]

# %% [markdown]
# ins = C3.index.to_list()
# import pickle
# with open('ins','wb') as f:
#     pickle.dump(ins,f)

# %%
C3.index.values.to_csv('Depthprof.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-2fb6df37d54e> in <module>()
# ----> 1 C3.index.values.to_csv('Depthprof.csv')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_csv'

# %%
C3.columns[0]
# Out:
# '20190910174210'

# %%
C4.columns[0]
# Out:
# '20190910174311'

# %%
s1[7:16]
# Out:
# 'channel 1'

# %%
M = fl[0]

# %%
import bisect
M[bisect.bisect_left(M, 'pt0919/channel 1/2019/sep/channel 1 20190910 155211 00001.ddf')]
# Out:
# 'pt0919/channel 1/2019/sep/channel 1 20190910 155211 00001.ddf'

# %%
M[bisect.bisect_right(M, 'pt0919/channel 1/2019/sep/channel 1 20190910 155211 00001.ddf'):]
# Out:
# ['pt0919/channel 1/2019/sep/channel 1 20190910 155611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 160011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 160411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 160811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 161211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 161611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 162011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 162411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 162811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 163211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 163611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 164011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 164411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 164811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 165211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 165611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 170011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 170411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 170811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 171211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 171611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 172011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 172412 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 172811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 173211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 173611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 174011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 174411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 174811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 175211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 175611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 180011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 180411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 180811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 181211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 181611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 182011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 182411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 182811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 183211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 183611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 184011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 184411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 184811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 185211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 185611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 190011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 190411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 190811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 191211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 191611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 192011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 192411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 192811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 193211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 193611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 194011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 194411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 194811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 195211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 195611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 200011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 200411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 200811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 201211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 201611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 202011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 202411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 202811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 203211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 203611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 204011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 204411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 204811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 205211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 205611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 210011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 210412 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 210811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 211211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 211611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 212011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 212411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 212811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 213211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 213611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 214011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 214411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 214811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 215212 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 215612 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 220011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 220411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 220811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 221212 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 221611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 222011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 222411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 222811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 223211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 223611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 224011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 224411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 224811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 225211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 225611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 230011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 230411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 230811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 231211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 231611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 232011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 232411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 232811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 233211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 233611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 234011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 234411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 234811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 235211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190910 235611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 000011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 000411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 000811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 001211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 001611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 002011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 002411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 002811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 003211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 003611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 004011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 004411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 004811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 005211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 005611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 010012 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 010411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 010811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 011211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 011611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 012011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 012411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 012812 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 013211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 013611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 014011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 014411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 014811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 015211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 015611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 020011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 020411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 020811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 021211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 021611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 022011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 022411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 022811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 023212 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 023611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 024011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 024411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 024811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 025211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 025611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 030011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 030411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 030811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 031211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 031611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 032012 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 032411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 032811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 033211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 033611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 034011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 034411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 034811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 035211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 035611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 040011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 040411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 040811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 041211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 041611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 042011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 042411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 042811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 043211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 043611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 044011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 044411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 044811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 045211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 045611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 050011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 050411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 050811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 051211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 051611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 052011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 052411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 052811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 053211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 053611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 054011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 054411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 054811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 055211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 055611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 060011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 060411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 060811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 061211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 061611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 062011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 062411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 062811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 063211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 063611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 064011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 064411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 064811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 065211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 065611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 070011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 070411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 070811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 071211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 071611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 072011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 072412 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 072811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 073211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 073611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 074011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 074411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 074811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 075211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 075611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 080011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 080411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 080811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 081211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 081611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 082011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 082411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 082811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 083211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 083611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 084011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 084411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 084811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 085211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 085612 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 090011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 090411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 090811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 091211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 091611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 092011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 092411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 092811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 093211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 093611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 094011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 094411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 094811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 095211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 095611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 100011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 100411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 100811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 101211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 101611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 102011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 102411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 102811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 103211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 103611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 104011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 104411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 104811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 105211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 105611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 110011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 110411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 110811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 111211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 111612 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 112011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 112411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 112811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 113211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 113611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 114011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 114411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 114811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 115211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 115611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 120011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 120412 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 120811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 121211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 121611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 122011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 122411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 122811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 123211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 123611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 124011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 124411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 124811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 125211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 125611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 130011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 130411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 130811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 131211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 131612 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 132011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 132411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 132811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 133211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 133611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 134011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 134411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 134811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 135211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 135611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 140011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 140411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 140811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 141211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 141611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 142011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 142411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 142811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 143211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 143611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 144011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 144411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 144811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 145211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 145611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 150011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 150411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 150811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 151211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 151611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 152012 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 152411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 152811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 153211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 153611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 154011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 154411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 154811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 155211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 155611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 160011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 160411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 160811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 161211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 161611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 162011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 162411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 162811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 163211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 163611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 174011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 174411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 174811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 175211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 175611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 180011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 180411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 180811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 181211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 181611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 182011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 182411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 182811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 183211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 183611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 184011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 184411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 184811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 185211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 185611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 190011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 190411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 190811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 191211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 191611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 192011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 192411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 192811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 193211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 193611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 194011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 194411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 194811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 195211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 195611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 200011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 200411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 200811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 201211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 201611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 202011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 202411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 202811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 203211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 203611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 204011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 204411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 204811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 205211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 205611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 210011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 210411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 210811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 211211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 211611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 212011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 212411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 212811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 213211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 213611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 214011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 214411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 214811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 215211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 215611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 220011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 220411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 220811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 221211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 221611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 222011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 222411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 222811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 223211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 223611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 224011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 224411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 224811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 225211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 225611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 230011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 230411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 230811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 231211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 231611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 232011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 232411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 232811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 233211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 233611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 234011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 234411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 234811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 235211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190911 235611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 000011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 000411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 000811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 001211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 001611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 002011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 002411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 002811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 003211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 003611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 004011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 004411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 004811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 005211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 005611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 010011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 010411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 010811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 011211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 011611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 012011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 012411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 012811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 013211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 013611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 014011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 014411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 014811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 015211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 015611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 020011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 020411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 020811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 021211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 021611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 022011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 022411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 022811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 023211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 023611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 024011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 024411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 024811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 025211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 025611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 030011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 030411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 030811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 031211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 031611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 032011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 032411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 032811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 033211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 033611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 034011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 034411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 034811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 035211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 035611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 040011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 040411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 040811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 041211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 041611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 042011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 042411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 042811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 043211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 043611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 044011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 044411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 044811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 045211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 045611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 050011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 050411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 050811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 051211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 051611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 052011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 052411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 052811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 053211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 053611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 054011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 054411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 054811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 055211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 055611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 060011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 060411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 060811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 061211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 061611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 062011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 062411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 062811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 063211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 063611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 064011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 064411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 064811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 065211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 065611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 070011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 070411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 070811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 071211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 071611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 072011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 072411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 072811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 073211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 073611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 074011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 074411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 074811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 075211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 075611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 080011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 080411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 080811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 081211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 081611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 082011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 082411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 082811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 083211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 083611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 084011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 084411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 084811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 085211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 085611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 090011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 090411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 090811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 091211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 091611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 092411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 092811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 093211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 093611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 094011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 094411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 094811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 095211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 095611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 100411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 100811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 101211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 101611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 102011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 102411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 102811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 103211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 103611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 104011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 104411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 104811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 105211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 105611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 110011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 110411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 110811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 111211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 111611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 112011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 112811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 113211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 113611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 114011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 114811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 115211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 115611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 120011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 120411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 120811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 121211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 121611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 122011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 122411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 122811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 123211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 123611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 124011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 124411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 124811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 125211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 125611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 130011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 130411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 130811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 131211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 131611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 132011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 132411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 132811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 133211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 133611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 134011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 134411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 134811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 135211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 135611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 140011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 140411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 140811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 141211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 141611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 142011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 142411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 142811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 143211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 144011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 144411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 144811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 145211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 145611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 150011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 150411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 150811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 151211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 151611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 152011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 152411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 152811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 153211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 153611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 154411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 154811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 155211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 155611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 160011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 160411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 160811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 161211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 161611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 162011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 162411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 162811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 163211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 163611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 164011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 164411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 164811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 165211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 165611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 170011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 170411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 170811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 171211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 171612 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 172011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 172411 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 172811 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 173211 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 173611 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 174011 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 174411 00001.ddf',
# ...
#  'pt0919/channel 1/2019/sep/channel 1 20190912 183134 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 183334 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 183434 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 183534 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 183634 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 183734 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 183834 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 183934 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 184034 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 184134 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 184234 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 184334 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 184434 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 184534 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 184634 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 184734 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 184834 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 184934 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 185034 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 185134 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 185234 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 185334 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 185434 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 185534 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 185634 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 185734 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 185834 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 185934 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 190034 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 190134 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 190234 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 190334 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 190434 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 190534 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 190634 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 190734 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 190834 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 190934 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 191134 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 191234 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 191334 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 191434 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 191534 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 191634 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 191734 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 191834 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 191934 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 192034 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 192134 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 192234 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 192334 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 192434 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 192534 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 192634 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 192734 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 192834 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 192934 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 193034 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 193134 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 193234 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 193334 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 193434 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 193634 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 193734 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 193834 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 193934 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 194034 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 194134 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 194234 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 194334 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 194434 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 194534 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 194634 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 194734 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 194834 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 194934 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 195034 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 195134 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 195234 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 195434 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 195534 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 195634 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 195734 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 195834 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 195934 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 200134 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 200234 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 200334 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 200434 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 200534 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 200634 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 200734 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 200834 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 200934 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 201034 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 201134 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 202235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 202635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 203035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 203435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 203835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 204235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 204636 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 205035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 205435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 205835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 210235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 210635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 211035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 211435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 211835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 212235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 212635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 213436 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 213835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 214235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 214635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 215035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 215435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 215835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 220235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 220635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 221035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 221435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 221835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 222235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 222635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 223035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 223435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 223835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 224235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 224635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 225035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 225435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 225835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 230235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 230635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 231035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 231435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 231835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 232235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 232635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 233035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 233435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 233835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 234635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 235035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 235435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190912 235836 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 000235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 000635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 001035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 001435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 001835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 002235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 002635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 003035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 003435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 003835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 004235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 004635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 005035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 005435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 005835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 011035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 011435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 011835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 012235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 012635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 013035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 013435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 013835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 014235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 014635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 015035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 015435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 015835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 020235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 020635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 021035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 021435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 021835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 022235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 022635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 023035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 023435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 023835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 024235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 024635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 025035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 025435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 025835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 030235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 030635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 031035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 031435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 031835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 032235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 032635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 033035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 033435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 033835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 034235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 034635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 035035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 035435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 035835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 040235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 040635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 041435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 041835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 042235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 042635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 043035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 043435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 043835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 044235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 044635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 045035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 045435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 045835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 050235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 050635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 051035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 051435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 051835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 052235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 052635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 053035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 053435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 053835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 054235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 054635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 055035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 055435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 060235 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 060635 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 061035 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 061435 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 061835 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 062636 00001.ddf',
#  'pt0919/channel 1/2019/sep/channel 1 20190913 063035 00001.ddf',
#  ...]
